# %%
import modal
QwenThreadedPipeline = modal.Cls.from_name("qwen_transcribe", "QwenPipeline")
pipeline = QwenThreadedPipeline()

# %%
url = "https://www.youtube.com/watch?v=DV0hw-0kiPw"
result = pipeline.transcribe_url.remote(url)

# %%
import json
print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# {
#   "segments": [
#     {
#       "text": "\u3068\u601d\u3063\u305f\u3089\u306d\u3001\u5168\u7136\u9055\u3063\u305f\u306e\u3002",
#       "words": []
#     },
#     {
#       "text": "\u3068\u601d\u3063\u305f\u3089\u306d\u3001\u5168\u7136\u9055\u3063\u305f\u306e\u3002 \u3042\u3001\u898b\u3066\u3002\u732b\u3061\u3083\u3093\u767a\u898b\u3057\u307e\u3057\u305f\u3002",
#       "words": []
#     },
#     {
#       "text": "\u3061\u3087\u3063\u3068\u3058\u3083\u3042\u306d\u3002\u3046\u3093\u3002\u3067\u3082\u6b21\u6765\u308b\u6642",
#       "words": []
#     },
#     {
#       "text": "\u3061\u3087\u3063\u3068\u3058\u3083\u3042\u306d\u3002\u3046\u3093\u3002\u3067\u3082\u6b21\u6765\u308b\u6642 \u30ea\u30d9\u30f3\u30b8\u3057\u307e\u3059\u3002\u5e30\u308c\u3061\u3083\u3063\u305f\u304b\u3089\u305d\u308c",
#       "words": []
#     },
#     {
#       "text": "\u3057",
#       "words": [
#         {
#           "token": "\u3057",
#           "start": 121.23,
#           "end": 122.19
# ...
